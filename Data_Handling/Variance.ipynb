# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# Taking a list of elements
data = [2, 4, 4, 4, 5, 5, 7, 9]
a = np.var(data)
df = pd.DataFrame({
 'data': data,
 'var': [4 for i in range(len(data))]})
df.plot()
plt.show()
